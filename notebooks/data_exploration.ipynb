# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('hello Amr entered from colab!')
# Out:
# hello Amr entered from colab!
